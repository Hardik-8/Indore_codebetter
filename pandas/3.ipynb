# %%
import pandas as pd

# %%
ind=['a','b','c','d','e']
emp={
    'emp_id':[101,102,103,104,105],
    "name":['raj','ravi','riya','hardik','harry'],
    'age':[26,25,27,25,28],
    'salary':[100000,200000,300000,10000,210000]
}

# %%
df=pd.DataFrame(emp,index=ind)
df
# Out:
#    emp_id    name  age  salary
# a     101     raj   26  100000
# b     102    ravi   25  200000
# c     103    riya   27  300000
# d     104  hardik   25   10000
# e     105   harry   28  210000

# %%
df.iloc[0]
# Out:
# emp_id       101
# name         raj
# age           26
# salary    100000
# Name: a, dtype: object

# %%
df.loc['a']
# Out:
# emp_id       101
# name         raj
# age           26
# salary    100000
# Name: a, dtype: object

# %%
df.iloc[0:2,[0,1,2,3]]
# Out:
#    emp_id  name  age  salary
# a     101   raj   26  100000
# b     102  ravi   25  200000

# %%
s=df['salary']
print(s)
s.sum()
# Out:
# a    100000
# b    200000
# c    300000
# d     10000
# e    210000
# Name: salary, dtype: int64
# np.int64(820000)

# %%
s.min()
# Out:
# np.int64(10000)

# %%
s.var()
# Out:
# np.float64(12430000000.0)

# %%
s.std()
# Out:
# np.float64(111489.90985734988)

# %%
age=df['age']

# %%
age
# Out:
# a    26
# b    25
# c    27
# d    25
# e    28
# Name: age, dtype: int64

# %%
age.min()
# Out:
# np.int64(25)

# %%
age.max()
# Out:
# np.int64(28)

# %%
age.var()
# Out:
# np.float64(1.7000000000000002)

# %%
age.mean()
# Out:
# np.float64(26.2)

# %%
sal_age=df[['age','salary']]

# %%
sal_age
# Out:
#    age  salary
# a   26  100000
# b   25  200000
# c   27  300000
# d   25   10000
# e   28  210000

# %%
sal_age.sum()
# Out:
# age          131
# salary    820000
# dtype: int64

# %%
sal_age.min()
# Out:
# age          25
# salary    10000
# dtype: int64

# %%
sal_age.mean()
# Out:
# age           26.2
# salary    164000.0
# dtype: float64

# %%
sal_age.std()
# Out:
# age            1.303840
# salary    111489.909857
# dtype: float64

# %%
sal_age.var()
# Out:
# age       1.700000e+00
# salary    1.243000e+10
# dtype: float64

# %%
sal_age.max()
# Out:
# age           28
# salary    300000
# dtype: int64

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [emp_id, name, age, salary]
# Index: []

# %%
df.head(5)
# Out:
#    emp_id    name  age  salary
# a     101     raj   26  100000
# b     102    ravi   25  200000
# c     103    riya   27  300000
# d     104  hardik   25   10000
# e     105   harry   28  210000

# %%
df.head(2)
# Out:
#    emp_id  name  age  salary
# a     101   raj   26  100000
# b     102  ravi   25  200000

# %%
df.head(10)
# Out:
#    emp_id    name  age  salary
# a     101     raj   26  100000
# b     102    ravi   25  200000
# c     103    riya   27  300000
# d     104  hardik   25   10000
# e     105   harry   28  210000

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [emp_id, name, age, salary]
# Index: []

# %% [markdown]
# ##head important hai

# %% [markdown]
# df.to_csv('employee.csv)

# %%
# df.to_csv('employee.csv')
