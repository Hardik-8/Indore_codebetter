# %%
import pandas as pd

# %%
student={
    "rollno":[101,102,103,104,None],
    "name":['raj','ravi','riya','hardik','tanvi'],
    "age":[20,22,21,None,22],
    'gender':['male','male','male','male','female'],
    "city":['indore','satna','katni',None,'maihar'] 
}
df=pd.DataFrame(student)

# %%
df.to_csv("student.csv",index=False)

# %%
df.to_excel("student.xlsx",index=False)

# %%
df.to_html('student.html',index=False)

# %%
df.to_json("student.json")

# %%
from sqlalchemy import create_engine

# %%
con_string="mysql+pymysql://root:0000@localhost:3306/pd_db"
engine=create_engine(con_string)

# %%
df.to_sql('student',if_exists='replace',con=engine,index=False)
# Out:
# 5
