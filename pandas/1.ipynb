# %%
import pandas as pd

# %%
ser = pd.Series([10,20,30,40,50])
print(ser)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
ser.dtype
# Out:
# dtype('int64')

# %%
ser.shape
# Out:
# (5,)

# %%
ser.median()
# Out:
# np.float64(30.0)

# %%
ser.ndim
# Out:
# 1

# %%
ser.size
# Out:
# 5

# %%
ser.max()
# Out:
# np.int64(50)

# %%
ser.sum()
# Out:
# np.int64(150)

# %%
ser.min()
# Out:
# np.int64(10)

# %%
ser.mean()
# Out:
# np.float64(30.0)

# %%
ser.var()
# Out:
# np.float64(250.0)

# %%
ser.std()
# Out:
# np.float64(15.811388300841896)

# %%
ser+4
# Out:
# 0    14
# 1    24
# 2    34
# 3    44
# 4    54
# dtype: int64

# %%
(ser+2)*8
# Out:
# 0     96
# 1    176
# 2    256
# 3    336
# 4    416
# dtype: int64

# %%
ser
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
ser//3
# Out:
# 0     3
# 1     6
# 2    10
# 3    13
# 4    16
# dtype: int64

# %%
ser/3
# Out:
# 0     3.333333
# 1     6.666667
# 2    10.000000
# 3    13.333333
# 4    16.666667
# dtype: float64

# %%
ser%12
# Out:
# 0    10
# 1     8
# 2     6
# 3     4
# 4     2
# dtype: int64

# %%
ser**3
# Out:
# 0      1000
# 1      8000
# 2     27000
# 3     64000
# 4    125000
# dtype: int64

# %%
ser2=pd.Series([20,30,40,50,60])

# %%
ser+ser2
# Out:
# 0     30
# 1     50
# 2     70
# 3     90
# 4    110
# dtype: int64

# %%
ser/ser2
# Out:
# 0    0.500000
# 1    0.666667
# 2    0.750000
# 3    0.800000
# 4    0.833333
# dtype: float64

# %%
ser//ser2
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
ser%ser2
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
ser**ser2
# Out:
# 0    7766279631452241920
# 1   -8070450532247928832
# 2    1696028571681685504
# 3                      0
# 4    1152921504606846976
# dtype: int64

# %%
ser*ser2
# Out:
# 0     200
# 1     600
# 2    1200
# 3    2000
# 4    3000
# dtype: int64

# %%
ser-ser2
# Out:
# 0   -10
# 1   -10
# 2   -10
# 3   -10
# 4   -10
# dtype: int64

# %%
ind=['a','b','c','d']
val=[11,22,33,44]

# %%
s1=pd.Series(val,index=ind)

# %%
s1
# Out:
# a    11
# b    22
# c    33
# d    44
# dtype: int64

# %%
s1=pd.Series(val,index=[12,13,14,15])
s1
# Out:
# 12    11
# 13    22
# 14    33
# 15    44
# dtype: int64

# %%
#methods 
# loc
# iloc

# %%
ser.loc[1]
# Out:
# np.int64(20)

# %%
ser
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
ser.iloc[2]
# Out:
# np.int64(30)

# %%
ser.loc['1']  #loc ke ander jo index hamne banai hai bas wahi pass kr sakte hai jo banai nahi hai vo pass krte hii error aa jaega
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 ser.loc['1']
#
# File c:\Users\nepro\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\nepro\anaconda3\Lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File c:\Users\nepro\anaconda3\Lib\site-packages\pandas\core\indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
# ...

# %%
pd.Series

# %%
sc_no1=['CD101','CD102','CD103','CD104','CD105']
fee1=[10000,20000,30000,40000,50000]

# %%
sc_no2=['CD102','CD101','CD103','CD105','CD104']
fee2=[340000,920000,230000,870000,650000]

# %%
ser1=pd.Series(fee1,index=sc_no1)
ser1
# Out:
# CD101    10000
# CD102    20000
# CD103    30000
# CD104    40000
# CD105    50000
# dtype: int64

# %%
ser2=pd.Series(fee2,index=sc_no2)
ser2
# Out:
# CD102    340000
# CD101    920000
# CD103    230000
# CD105    870000
# CD104    650000
# dtype: int64

# %%
ser1+ser2
# Out:
# CD101    930000
# CD102    360000
# CD103    260000
# CD104    690000
# CD105    920000
# dtype: int64

# %%
for i in range(ser1.size):
    print(ser1.iloc[i])
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000

# %%
i=0
while i < (ser1.size):
    print(ser1.iloc[i])
    i=i+1
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000

# %%
ser1.iloc[1:3]
# Out:
# CD102    20000
# CD103    30000
# dtype: int64

# %%
ser1.iloc[:]
# Out:
# CD101    10000
# CD102    20000
# CD103    30000
# CD104    40000
# CD105    50000
# dtype: int64

# %%
ser3=pd.Series(fee1,dtype='int32')
