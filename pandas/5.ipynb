# %%
import pandas as pd

# %%
student={
    "rollno":[101,102,103,104,None],
    "name":['raj','ravi','riya','hardik','tanvi'],
    "age":[20,22,21,None,22],
    'gender':['male','male','male','male','female'],
    "city":['indore','satna','katni',None,'maihar']
    
}

# %%
df=pd.DataFrame(student)
df
# Out:
#    rollno    name   age  gender    city
# 0   101.0     raj  20.0    male  indore
# 1   102.0    ravi  22.0    male   satna
# 2   103.0    riya  21.0    male   katni
# 3   104.0  hardik   NaN    male    None
# 4     NaN   tanvi  22.0  female  maihar

# %%
df.isna()
# Out:
#    rollno   name    age  gender   city
# 0   False  False  False   False  False
# 1   False  False  False   False  False
# 2   False  False  False   False  False
# 3   False  False   True   False   True
# 4    True  False  False   False  False

# %%
df1=df.dropna()

# %%
df1
# Out:
#    rollno  name   age gender    city
# 0   101.0   raj  20.0   male  indore
# 1   102.0  ravi  22.0   male   satna
# 2   103.0  riya  21.0   male   katni

# %%
df2=df.fillna("new data")

# %%
df2
# Out:
#      rollno    name       age  gender      city
# 0     101.0     raj      20.0    male    indore
# 1     102.0    ravi      22.0    male     satna
# 2     103.0    riya      21.0    male     katni
# 3     104.0  hardik  new data    male  new data
# 4  new data   tanvi      22.0  female    maihar

# %%
df2=df.fillna(df['age'].mean())

# %%
df2
# Out:
#    rollno    name    age  gender    city
# 0  101.00     raj  20.00    male  indore
# 1  102.00    ravi  22.00    male   satna
# 2  103.00    riya  21.00    male   katni
# 3  104.00  hardik  21.25    male   21.25
# 4   21.25   tanvi  22.00  female  maihar

# %%
df3=df.fillna({'age':df['age'].mean(),'city':df['city'].fillna("jbp")})

# %%
df3
# Out:
#    rollno    name    age  gender    city
# 0   101.0     raj  20.00    male  indore
# 1   102.0    ravi  22.00    male   satna
# 2   103.0    riya  21.00    male   katni
# 3   104.0  hardik  21.25    male     jbp
# 4     NaN   tanvi  22.00  female  maihar

# %%
df=pd.read_csv("Ecommerce_Consumer_Behavior_Analysis_Data.csv")

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Age, Gender, Income_Level, Marital_Status, Education_Level, Occupation, Location, Purchase_Category, Purchase_Amount, Frequency_of_Purchase, Purchase_Channel, Brand_Loyalty, Product_Rating, Time_Spent_on_Product_Research(hours), Social_Media_Influence, Discount_Sensitivity, Return_Rate, Customer_Satisfaction, Engagement_with_Ads, Device_Used_for_Shopping, Payment_Method, Time_of_Purchase, Discount_Used, Customer_Loyalty_Program_Member, Purchase_Intent, Shipping_Preference, Time_to_Decision]
# Index: []
#
# [0 rows x 28 columns]

# %%
df.dropna()
# Out:
#      Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 1    29-392-9296   49    Male         High        Married     High School
# 2    84-649-5117   24  Female       Middle         Single        Master's
# 6    90-144-9193   21  Female       Middle       Divorced     High School
# 8    37-065-3182   24  Female         High       Divorced        Master's
# 10   44-674-4037   33    Male       Middle       Divorced      Bachelor's
# ..           ...  ...     ...          ...            ...             ...
# 994  08-185-6608   32  Female         High       Divorced        Master's
# 996  41-366-4205   50  Female         High         Single     High School
# 997  77-241-7621   26    Male         High        Married      Bachelor's
# 998  53-091-2176   21  Female         High        Widowed      Bachelor's
# 999  48-203-9118   21  Female       Middle         Single     High School
#
#     Occupation     Location     Purchase_Category Purchase_Amount  ...  \
# ...

# %%
df=pd.read_csv("ecommerce_dataset_20cols.csv")

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [OrderID, CustomerID, CustomerName, Email, Phone, City, State, Country, ProductID, ProductName, Category, Price, Quantity, Discount, PaymentMethod, OrderDate, DeliveryDate, OrderStatus, Rating, ReturnStatus]
# Index: []

# %%
df.dropna()
# Out:
#       OrderID  CustomerID CustomerName        Email         Phone    City  \
# 22         23        1087         Amit  c@gmail.com  1.000000e+10  Mumbai
# 38         39        1448         Amit  c@gmail.com  7.777778e+09  Bhopal
# 60         61        1510          Raj  c@gmail.com  7.777778e+09   Delhi
# 74         75        1273         Amit  b@gmail.com  7.777778e+09   Delhi
# 284       285        1032         Amit  a@gmail.com  7.777778e+09  Bhopal
# 288       289        1138         Sara  a@gmail.com  8.888889e+09  Mumbai
# 353       354        1376         Amit  c@gmail.com  7.777778e+09  Mumbai
# 468       469        1949         Sara  a@gmail.com  8.888889e+09  Indore
# 492       493        1786         Amit  c@gmail.com  7.777778e+09  Mumbai
# 516       517        1648         Sara  c@gmail.com  8.888889e+09  Bhopal
# 549       550        1697         Amit  a@gmail.com  1.000000e+10  Indore
# 554       555        1371         John  b@gmail.com  1.000000e+10  Bhopal
# ...
