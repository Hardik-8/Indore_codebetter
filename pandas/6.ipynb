# %%
import pandas as pd

# %%
df=pd.read_csv("file1.csv")

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Order_ID, Customer_ID, Customer_Name, Email, Phone, Age, Gender, City, State, Country, ZIP_Code, Product_Category, Product_Name, SKU, Quantity, Unit_Price, Discount_%, Total_Amount, Order_Date, Ship_Date, Delivery_Date, Payment_Method, Order_Status, Sales_Rep, Department, Rating, Return_Reason, Is_Repeat_Customer, Loyalty_Points, Notes]
# Index: []
#
# [0 rows x 30 columns]

# %%
print(df)
# Out:
#        Order_ID Customer_ID   Customer_Name                         Email  \
# 0     ORD-10031   CUST-4688  Priya Williams  priya.williams17@hotmail.com
# 1     ORD-10109   CUST-4243    David Chopra    david.chopra64@outlook.com
# 2     ORD-10136   CUST-2721    Amanda Jones      amanda.jones37@yahoo.com
# 3     ORD-10088   CUST-1264  Aarav Williams    aarav.williams52@yahoo.com
# 4     ORD-10918   CUST-3103     Maria Brown      maria.brown42@company.in
# ...         ...         ...             ...                           ...
# 1025  ORD-10087   CUST-1645      Juan Smith        juan.smith41@yahoo.com
# 1026  ORD-10330   CUST-2277     Maria Joshi       maria.joshi92@yahoo.com
# 1027  ORD-10466   CUST-4073     Rahul Davis     rahul.davis13@outlook.com
# 1028  ORD-10121   CUST-1318    Rohit Miller    rohit.miller34@hotmail.com
# 1029  ORD-10860   CUST-4266     Maria Brown       maria.brown36@gmail.com
#
#                Phone   Age  Gender          City         State  Country  ...  \
# ...

# %%
df1=df.dropna()
# df1.head(0)
print(df1)
# Out:
#        Order_ID Customer_ID      Customer_Name  \
# 17    ORD-10664   CUST-4055  Isabella Williams
# 85    ORD-10086   CUST-2877       Pedro Sharma
# 116   ORD-10757   CUST-4118       Ana Williams
# 132   ORD-10628   CUST-1648     Divya Williams
# 141   ORD-10869   CUST-3843        Rohit Smith
# 168   ORD-10478   CUST-2499      Jessica Mehta
# 253   ORD-10440   CUST-1304      Jessica Davis
# 254   ORD-10346   CUST-4047       Rahul Garcia
# 272   ORD-10359   CUST-4576        Emily Smith
# 331   ORD-10518   CUST-4979      Sarah Johnson
# 494   ORD-10636   CUST-4117       Rahul Garcia
# 530   ORD-10124   CUST-4518       Rahul Garcia
# 541   ORD-10099   CUST-1669        Pedro Patel
# 565   ORD-10271   CUST-3305      Vikram Sharma
# 572   ORD-10578   CUST-3043        Sofia Gupta
# 590   ORD-10263   CUST-1812       Vikram Verma
# 598   ORD-10124   CUST-4518       Rahul Garcia
# 624   ORD-10287   CUST-2548        Luis Wilson
# 739   ORD-10751   CUST-1439       Pooja Wilson
# ...

# %%
df2=df.fillna("data")

# %%
df2
# Out:
#        Order_ID Customer_ID   Customer_Name                         Email  \
# 0     ORD-10031   CUST-4688  Priya Williams  priya.williams17@hotmail.com
# 1     ORD-10109   CUST-4243    David Chopra    david.chopra64@outlook.com
# 2     ORD-10136   CUST-2721    Amanda Jones      amanda.jones37@yahoo.com
# 3     ORD-10088   CUST-1264  Aarav Williams    aarav.williams52@yahoo.com
# 4     ORD-10918   CUST-3103     Maria Brown      maria.brown42@company.in
# ...         ...         ...             ...                           ...
# 1025  ORD-10087   CUST-1645      Juan Smith        juan.smith41@yahoo.com
# 1026  ORD-10330   CUST-2277     Maria Joshi       maria.joshi92@yahoo.com
# 1027  ORD-10466   CUST-4073     Rahul Davis     rahul.davis13@outlook.com
# 1028  ORD-10121   CUST-1318    Rohit Miller    rohit.miller34@hotmail.com
# 1029  ORD-10860   CUST-4266     Maria Brown       maria.brown36@gmail.com
#
#                Phone   Age  Gender          City         State  Country  ...  \
# ...

# %%
df2.head(0)
# Out:
# Empty DataFrame
# Columns: [Order_ID, Customer_ID, Customer_Name, Email, Phone, Age, Gender, City, State, Country, ZIP_Code, Product_Category, Product_Name, SKU, Quantity, Unit_Price, Discount_%, Total_Amount, Order_Date, Ship_Date, Delivery_Date, Payment_Method, Order_Status, Sales_Rep, Department, Rating, Return_Reason, Is_Repeat_Customer, Loyalty_Points, Notes]
# Index: []
#
# [0 rows x 30 columns]
