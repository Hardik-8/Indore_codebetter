# %%
#list of object 
class Student:
    def __init__(self,rollno=0,name=""):
        self.rollno=rollno
        self.name=name
        self.marks={"hindi":0,"eng":0,"phy":0}
    def input(self):
        self.rollno=int(input("enter rollno"))
        self.name=int(input("enter name"))
        self.marks["hindi"]=int(input("enter marks"))
        self.marks["eng"]=int(input("enter marks"))
        self.marks["phy"]=int(input("enter marks"))
    def display(self):
        print(self.rollno,",",self.name,",",self.marks,",",)
    def __str__(self):
        return "student"+ str(self.rollno)+ ","+self.name

s1=Student(10,"hardik")
s1.marks={"hindi":90,"eng":80,"phy":70}
s1.display()

s2=Student(11,"rahul")
s2.marks={"hindi":80,"eng":70,"phy":60}
s2.display()
        
student=[s1,s2]
print(student)
print(s1)
print(s2)
# Out:
# 10 , hardik , {'hindi': 90, 'eng': 80, 'phy': 70} ,
# 11 , rahul , {'hindi': 80, 'eng': 70, 'phy': 60} ,
# [<__main__.Student object at 0x000001AE751CC5F0>, <__main__.Student object at 0x000001AE751CED80>]
# student10,hardik
# student11,rahul

# %%
print(len(student))
s3=Student(12,"arjav")
s3.marks={"hindi":90,"eng":80,"phy":70}
student.append(s3)

s4=Student(13,"karan")
s4.marks={"hindi":90,"eng":80,"phy":70}
student.append(s4)
s5=Student(14,"rohan")
s5.marks={"hindi":90,"eng":80,"phy":70}
# Out:
# 5

# %%
for i in range(len(student)):
    stu=student[i]
    # print(stu)
    total=stu.marks["hindi"] +stu.marks["eng"] +stu.marks["phy"] 
    print(stu,total)
    # tot=student[i].display()
    # # print(tot)
# Out:
# student10,hardik 240
# student11,rahul 210
# student12,arjav 0
# student13,karan 0
# student14,rohan 0
# student12,arjav 240
# student13,karan 240

# %%
# Out:
# student13,karan
