# %%
class Student:
    def __init__(self):
        self.rollno=0
        self.name=""
        self.__grade="F"  #kahi bhi __ double underscore bana do to vo eek private variable ban jata hai 

    def display(self):
        print(self.rollno,self.name,self.__grade)
    
    def setGrade(self):
        percent=float(input("enter the percentage"))
        if percent>0 and percent<=40:
            self.__grade="F"
        elif percent>40 and percent<=60:
            self.__grade="C"
        elif percent>60 and percent<=80:
            self.__grade="B"
        elif percent>80 and percent<=100:
            self.__grade="A"
        else:
            print("invalid marks")


        
#Has - A relationship refers to composition or aggegation.
s1=Student()
s1.rollno=101
s1.name="hardik"
s1.__grade="A"
s1.display()
s1.setGrade()
s1.display()
# Out:
# 101 hardik F
# 101 hardik C

# %%
def setGrade(self):
    percent=float(input("enter the percentage"))
    if percent>0 and percent<=40:
        self.__grade="F"
    elif percent>40 and percent<=60:
        self.__grade="C"
    elif percent>60 and percent<=80:
        self.__grade="B"
    elif percent>80 and percent<=100:
        self.__grade="A"
    else:
        print("invalid marks")
