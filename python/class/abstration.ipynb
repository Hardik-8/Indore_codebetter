# %%
#abstraction means hinding unnecessary details and showing only what is required

from abc import ABC , abstractmethod 
class vechicle(ABC):
    @abstractmethod
    def start(self):
       pass

class car(vechicle):
    def start(self):
        print("car started ")

c1=car()
c1.start()
# Out:
# car started
