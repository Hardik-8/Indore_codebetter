# %%
a=int(input("Enter first value "))
b=int(input("enter second value "))
temp=a
a=b
b=temp
print(a)
print(b)
# Out:
# 6
# 5

# %%
a=int(input("Enter first value "))
b=int(input("Enter second value "))
if(a%b==0):
    print("a is divisible by b")
else:
    print("a is not divisible by b")
# Out:
# a is not divisible by b

# %%
a=int(input("Enter first value "))
c=a/2000
d=a%2000
print(c)
print(d)
# Out:
# 51
# 20

# %%
a=int(input("Enter first value "))
c=a//365
d=a//7
e=a//30&a//31
print(c)
print(d)
print(e)
# Out:
# 2
# 142
# 32

# %%
a=int(input("Enter first value "))
if(a>=100&a<=999):
    c=a[0]+a[1]+a[2]
    print("the sum of the three digits is : ",c)
else:
    print("the number is not a three digit number")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 a=int(input("Enter first value "))
#       2 if(a>=100&a<=999):
# ----> 3     c=float(a[0]+a[1]+a[2])
#       4     print("the sum of the three digits is : ",c)
#       5 else:
#
# TypeError: 'int' object is not subscriptable
