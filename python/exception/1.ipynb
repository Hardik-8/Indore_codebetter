# %%
print(hello")
# Out:
#   Cell In[1], line 1
#     print(hello")
#                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
if True:
a=10
# Out:
#   Cell In[2], line 2
#     a=10
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
a=10
a='10'
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 a=10
#       2 a='10'
# ----> 3 print(a+b)
#
# NameError: name 'b' is not defined

# %%
try :
    a=10
    b='10'
    c=a/b
except :
     print("you can use only same datatype in both variable")

finally:
     print("hello world")
# Out:
# you can use only same datatype in both variable
# hello world

# %%
try:
    a=int(input("enter any number"))
    b=int(input("enter any number"))
    c=a/b
except:
    print("you can only use same data type ")
else:
    print("divient is ",c)
finally:
    print("hello world")
# Out:
# divient is  1.0
# hello world
