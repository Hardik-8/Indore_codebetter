# %%
a=int(input("enter any number"))
b=int(input("enter any number"))
try:
    c=a/b
except :
    print("use integer only")
else:
    print(c)
finally:
    print("hello")   

#except ke sath ham koi sa bhi erro likh sakte hai mtlb ki value error name erro or zero division error ya koi sa bhi error
# Out:
# 1.0
# hello

# %%
def check_num(num=int):
    try:
        num=int(input("Enter any number"))
        if num%2==0:
            print("number is even")
        else : 
            print("number is odd")
    except :
        print("use integer")
#compile time erro ko handle nahi kr sakte runtime bas kr sakte hai
check_num()
# Out:
# number is even

# %%
class Myerror(Exception):
    pass

try:
    age = int(input("enter your age"))
    if age>18:
        print("you are eligible")
    else:
        print("not eligible")
        # raise Myerror
except Myerror :
    print("invlaid age")
# Out:
#   Cell In[25], line 5
#     if age>18:
#     ^
# SyntaxError: expected 'except' or 'finally' block
