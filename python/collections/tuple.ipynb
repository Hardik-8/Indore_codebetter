# %% [markdown]
# # whenver we want to represent group me indiviual object as a single entity where homogenous hetrogenous object and duplicate object is to be allowd and insertion order is to be prserved but we want to immutatble operation then we will use tuple .

# %%
# ( )
ls=[]
n=int(input("enter"))
for i in range(1,n+1):
    print("enter",i,"record")
    data=int(input("enter any roll_no"))
    name=input("enter the name")
    marks=int(input("enter the marks"))
    s=(data,name,marks)
    ls.append(s)

for i in ls:
    print(i)
# Out:
# enter 1 record
# (20, 'j', 54)

# %%
t=(1,2,3,4,5,6,7,8)

# %%
print(t)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8)

# %%
t[1:7]
# Out:
# (2, 3, 4, 5, 6, 7)

# %%
print(len(t))
# Out:
# 8

# %%
t[min(t)]
# Out:
# 2

# %%
print(max(t))
# Out:
# 8

# %%
t.index(3)
# Out:
# 2

# %%
max(t)
# Out:
# 8

# %%
t.count(2)
# Out:
# 1

# %%
t=list(t)

# %%
t.append(9)

# %%
t=tuple(t)

# %%
print(t)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9)

# %%
tp=(67,63,58)
print(tp)
# Out:
# (67, 63, 58)

# %%
tp=1,2,3,4    #ham comma se seperate krte hai tab bhi vo tuple ban jata hai
print(tp)
# Out:
# (1, 2, 3, 4)

# %%
tp1,tp2=2,5
print(tp1,tp2) # we can store multiple like this
# Out:
# 2 5

# %%
tp1=tp2=tp3=67
print(tp3)
# Out:
# 67

# %%
s1={1,2,3,4,5} # this is set

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
#{} # isko use krne se dictionary banti hai jiske ander key value pair hote hai 
d1={101:"jay",102:"jaya",103:"venu",104:"raju",105:"aman"}
print(d1)
# Out:
# {101: 'jay', 102: 'jaya', 103: 'venu', 104: 'raju', 105: 'aman'}

# %%
print(d1[102])
d1[105]="raman"
print(d1)
# Out:
# jaya
# {101: 'jay', 102: 'jaya', 103: 'venu', 104: 'raju', 105: 'raman'}

# %%
print(c[101])
#method of dictionary 
    # 1.clear
    # 2.get 
    # 3.items
    # 4.keys
    # 5.pop
    # 6.update 
print(d1.keys())
d1.values()
print(d1.items())
# Out:
# ('roll no', 1, 20000)
# dict_keys([101, 102, 103, 104, 105])
# dict_items([(101, 'jay'), (102, 'jaya'), (103, 'venu'), (104, 'raju'), (105, 'raman')])

# %%
d=("roll no",1,20000)
# d=["roll",1,3]
c={101:d,102:"roll no"}
# print(c)

for i in c:
    print(c[i])
    print(c.get(1))
# Out:
# ('roll no', 1, 20000)
# None
# roll no
# None
