# %%
#cercumference of 
			#faranite in centegrate

# %%
a = int(input("Enter percentage: "))
if a < 0 or a >=101:
    print("invalid")
elif a < 45:
    print("3rd division")
elif a < 60:
    print("2nd division")
elif a < 101:
    print("1 st division")
elif a <= 33:
    print("Fail")
# Out:
# 3rd division

# %%
a = int(input("Enter percentage: "))
if a < 0 or a >=100:
    print("invalid")
elif a >= 60:
    print("1st division")
elif a >= 45:
    print("2nd division")
elif a >= 33:
    print("3rd division")
else:
    print("Fail")
# Out:
# invalid

# %%
#find the greatest number from 4 inputs
a = int(input("Enter the value of a: "))
b = int(input("Enter the value of b: "))
c = int(input("Enter the value of c: "))
d = int(input("Enter the value of d: "))
if a > b and a > c and a > d:
    print("a is greater")
elif b > a and b > c and b > d:
    print("b is greater")
elif c > a and c > b and c > d:
    print("c is greater")
else:
    print("d is greater")
# Out:
# a is greater

# %%
#PCM marks
P = int(input("Enter the marks of physics :"))
C = int(input("Enter the marks of chemsitry :"))
M = int(input("Enter the marks of maths :"))
print("Physics:",P)
print("Chemistry:",C)
print("Maths:",M)
tot=P+C+M
c=(tot/300)*100
if P<33 and C<33 and M<33:
    print("fail in all")
elif(P<33 and C<33) or (P<33 and M<33) or (C<33 and M<33):
    print("fail in two subjects")
    if P<33 and C<33:
        print("fail in Physics and Chemistry")
    elif P<33 and M<33:
        print("fail in physics and Maths")
    else:
        print("fail in chemistry and maths")
elif P<33 or C<33 or M<33:
    print("fail in one subject")
    if P<33:
        print("fail in physics")
    elif C<33:
        print("Fail in chemistry")
    else:
        print("Fail in Maths")
elif (P>33 and P<=100) and (C>33 and C<=100) and (M>33 and M<=100):
    print("pass in all the subjects ")
    print("total marks are ",P+C+M) 
    print("total percentage are ",c)
    if c < 0 or c >=100:
        print("invalid")
    elif c >= 60:
        print("1st division")
    elif c >= 45:
        print("2nd division")
    elif c >= 33:
        print("3rd division")
    else:
        print("3rd")
else:
    print("marks cannot be more than 100")
# Out:
# Physics: 9
# Chemistry: 45
# Maths: 2
# fail in any two subjects
# fail in physics and Maths

# %%
# -------- Student Details --------
university = "AKS University"

name = input("Enter Name : ")
course = input("Enter Course : ")
roll = input("Enter Roll No : ")
branch = input("Enter Branch : ")
fname = input("Enter Father's Name : ")
sem = input("Enter Semester : ")

# -------- Subjects --------
sub1 = "Physics"
sub2 = "Chemistry"
sub3 = "Maths"

# -------- Marks Input --------
P = int(input("Enter Physics Marks : "))
C = int(input("Enter Chemistry Marks : "))
M = int(input("Enter Maths Marks : "))

# -------- Validation --------
if P > 100 or C > 100 or M > 100:
    print("❌ Marks cannot be greater than 100")
    exit()

# -------- Total & Percentage --------
total = P + C + M
percentage = (total / 300) * 100

# -------- Result Logic --------
fail_count = 0
failed_subjects = []

if P < 33:
    fail_count += 1
    failed_subjects.append("Physics")
if C < 33:
    fail_count += 1
    failed_subjects.append("Chemistry")
if M < 33:
    fail_count += 1
    failed_subjects.append("Maths")

if fail_count == 0:
    result = "PASS"
    if percentage >= 60:
        division = "First Division"
    elif percentage >= 45:
        division = "Second Division"
    else:
        division = "Third Division"
else:
    result = "FAIL"
    division = "----"

# -------- Marksheet Print --------
print("\n\t==============================================================")
print("\t\t\t\t", university)
print("\t==============================================================\n")

print("\tName :", name, "\t\tCourse :", course)
print("\tRoll :", roll, "\t\tBranch :", branch)
print("\tFName:", fname, "\t\tSemester:", sem)

print("\n\t--------------------------------------------------------------")
print("\t Subject\tMin Marks\tMarks Obtain\tTotal")
print("\t--------------------------------------------------------------")
print("\t Physics\t33\t\t", P, "\t\t100")
print("\t Chemistry\t33\t\t", C, "\t\t100")
print("\t Maths\t\t33\t\t", M, "\t\t100")
print("\t--------------------------------------------------------------")

print("\t Total Marks :", total, "/300")
print("\t Percentage  :", round(percentage, 2), "%")
print("\t Result      :", result)
print("\t Division    :", division)

if fail_count > 0:
    print("\t Failed In   :", ", ".join(failed_subjects))

print("\n\t Date : 04/02/2026\t\tController of Examination")
print("\t==============================================================")
# Out:
# ...
# 				 AKS University
# ...
#
# 	Name : HARDIK 		Course : HHD
# 	Roll : D 		Branch : D
# 	FName: D 		Semester: D
#
# 	--------------------------------------------------------------
# 	 Subject	Min Marks	Marks Obtain	Total
# 	--------------------------------------------------------------
# 	 Physics	33		 12 		100
# 	 Chemistry	33		 10 		100
# 	 Maths		33		 9 		100
# 	--------------------------------------------------------------
# 	 Total Marks : 31 /300
# 	 Percentage  : 10.33 %
# 	 Result      : FAIL
# 	 Division    : ----
# 	 Failed In   : Physics, Chemistry, Maths
#
# 	 Date : 04/02/2026		Controller of Examination
# ...

# %%
a="HARDIk"
a.lower()
a.upper()
i
# Out:
# 'HARDIK'

# %%
P = int(input("Enter Basic Salary :"))
c=(P*20)/100
d=(P*80)/100
e=(P*25)/100
f=(P*90)/100
g=(P*30)/100
h=(P*95)/100
if P<=10000:
    print("the gross salary is",P+c+d)
elif P<=20000:
    print("Your gross salary is",P+e+f)
else:
    print("Your gross salary is",P+g+h)
# Out:
# Your gross salary is  43000.0

# %%
P = int(input("Enter the Salary :"))
C = int(input("Enter the tenure "))
if P<20000 and C>3:
    print("you will get bonus!!!")
else:
    print("You will not get bonus!!!")
# Out:
# You will not get bonus!!!

# %%
P = (input("Enter your gender M/F:"))
C = int(input("Enter the lunch time :"))
if P==M and C==2:

# %%
P = input("Enter your gender M/F:")
C = int(input("Enter the lunch time :"))
if P=="M" and C==2:
	print("you can have Lunch — 600–650 kcal 2 roti → 200 kcal Dal → 200 kcal Sabzi → 100 kcal Curd → 100 kcalTotal ≈ 600 kcal")
elif P=="F" and C==2:
	print("you can have Lunch — 500–650 kcal 2 roti → 200 kcal Dal → 200 kcal Sabzi → 100 kcal Curd → 100 kcalTotal ≈ 500 kcal")
elif P=="M" and C==1:
	print("you can have Lunch — 400–650 kcal 2 roti → 200 kcal Dal → 200 kcal Sabzi → 100 kcal Curd → 100 kcalTotal ≈ 400 kcal")
elif P=="F" and C==1:
	print("you can have Lunch — 300–650 kcal 2 roti → 200 kcal Dal → 200 kcal Sabzi → 100 kcal Curd → 100 kcalTotal ≈ 300 kcal")
elif P=="M" and C==12:
	print("you can have Lunch — 200–650 kcal 2 roti → 200 kcal Dal → 200 kcal Sabzi → 100 kcal Curd → 100 kcalTotal ≈ 200 kcal")
elif P=="F" and C==12:
	print("you can have Lunch — 100–650 kcal 2 roti → 200 kcal Dal → 200 kcal Sabzi → 100 kcal Curd → 100 kcalTotal ≈ 100 kcal")
else:
	print("you cannot have lunch")
# Out:
# the area of cube is :  216.0

# %%
P = int(input("Enter the unit of last month :"))
C = int(input("Enter the unit of current month :"))
if (P>0 and P<151) and (C>0 and C<151):
    print("Your bill of last month is ",P*4)
    print("Your bill of current month is ",C*4)
elif (P>150 and P<301) and (C>151 and C<301):
    print("Your bill of last month is ",P*6)
    print("Your bill of current month is ",C*6)
elif (P>300 and P<501) and (C>300 and C<501):
    print("Your bill of last month is ",P*8)
    print("Your bill of current month is ",C*8)
elif (P>500) and C>500:
    print("Your bill of last month is ",P*10)
    print("Your bill of current month is ",C*10) 
else :
    print("too much bill diffrence in both the month ")
# Out:
# too much bill in both the month

# %%
print("THIS IS CALL CENTER \n Enter 1 for prepaid services \n Enter 2 for post paid services \n Enter 3 for network problems \n Enter 9 for talking to an agent")
P = int(input("Enter the number shown above :"))
if P==1:
    print("Prepaid entered")
    print("press \n1.For recharge \n2.For data usage \n3.for OTT")
    d=input("enter a number for going forward")
    print(d)
    if d==1:
        print("recharge plans are ....")
    elif d==2:
        print("data use is ....")
    else:
        print("ott are netflix , joihoststar ....")
elif P==2:
    print("Postpaid services ")
    print("press \n1.calling related \n2.SMS related \n3.international roaming ")
    e=input("enter a number for going forward ")
    print(e)
    if e==1:
        print("Calling plans are....")
    elif e==2:
        print("SMS  related plans are....")
    else :
        print("International roaming plans....")
elif P==3:
    print("Network Problem listed")
    f=input("enter the area ")
    print(f)
    if f=="satna" or f=="indore" or f=="rewa":
        print("these area are afected b the net and server is down")
    else:
        print("these area have stable net .Try to restart your mobile")
elif P==9:
    print("agent will join the call in some time just wait a while")
    print("agent here thanks for calling ")
else :
    print("invalid input entered")
# Out:
# THIS IS CALL CENTER
#  Enter 1 for prepaid services
#  Enter 2 for post paid services
#  Enter 3 for network problems
#  Enter 9 for talking to an agent
# Prepaid entered
# press
# 1.For recharge
# 2.For data usage
# 3.for OTT
# 3
# ott are netflix , joihoststar ....

# %%
sum=0
i=1
n=int(input("enter the value of n :"))
while i<=n:
	
	sum=sum+i
	
	i=i+1
print("=",sum)
#1+2+3+4 ese krke likhna hai
# Out:
# = 15

# %%
#print first n natural number ki series banani hai 
sum=0
i=1
n=int(input("enter the value of n :"))
while i<=n:
	sum=i*i
	sum1=sum+i
	print(sum)
	print(sum1)
	i=i+1
# Out:
# 1
# 2
# 4
# 6
# 9
# 12
# 16
# 20
# 25
# 30
# 36
# 42
# 49
# 56

# %%
n=7
i=1
while i<=10:
    res=n*i
    print(n,'*',i,'=',res)
    i=i+1
# Out:
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 7 * 10 = 70

# %%
#print first n natural number ki series banani hai 
#sum=0
i=1
n=int(input("enter the value of n :"))
while i<=n:
	sum=i%2!=0
	
	i=i+1
	print(sum)
# Out:
# True
# False
# True
# False
# True
# False
# True
# False

# %% [markdown]
# Write a program to find gross salary (Hint :-GS=BS+DA+TA).

# %%
#print first n natural number ki series banani hai 
sum=0
i=1
res=1
n=int(input("enter the value of n :"))
while i<=n:
	
	sum=sum+res
	res=res*i
	
	
	i=i+1
print(res)
# Out:
# 120

# %%
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    sum=sum+fact
    i=i+1
print("the value of n is ",n)
print("factorial ",fact,'The sum is ',sum)
    
#sum=(sum+fact)/i
#1/!l1
# Out:
# the value of n is  5
# factorial  120 The sum is  153

# %%
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    if i%2==0:
    
        sum=sum+fact
    else : 
        sum=sum-fact
    i=i+1
print("the value of n is ",n)

print('The + - + - series is ',sum)
# Out:
# the value of n is  5
# factorial  120
# The + - + - series is  -101

# %%
#9
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    if i%2==0:
        k=(fact/i)*2-1
        sum=sum-k
    else : 
        k=(fact/i)*2-1
        sum=sum+k
    i=i+1
print("the value of n is ",n)
print('The + - + - series is ',sum)
# Out:
# the value of n is  5
# The + - + - series is  39.0

# %%
#1
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    k=fact/i
    sum=sum+k
    i=i+2

print(sum)
# Out:
# 5.0

# %%
# Out:
# 10.0

# %%
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    sum=(sum+fact)/i
    
    i=i+1
print("the value of n is ",n)
print("factorial ",fact)
print('The + - + - series is ',sum)
# Out:
# the value of n is  5
# factorial  120
# The + - + - series is  25.325

# %%
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    k=fact/i
    sum=sum+k
    i=i+1
# print("the value of n is ",n)
# print("factorial ",fact,'The sum is ',sum)
print(sum)
#sum=(sum+fact)/i
#1/!l1
# Out:
# the value of n is  5
# factorial  120 The sum is  34.0

# %%
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    
    sum=sum+fact
    fact=sum/i
    i=i+1
print("the value of n is ",n)
print("factorial ",fact,'The sum is ',sum)
    
#sum=(sum+fact)/i
#1/!l1
# Out:
# the value of n is  5
# factorial  1.0 The sum is  5.0

# %%
# table banani hai 
# eek sereis banani hai jisme 1,2,4,7,11,16,22,29
n=10
i=1
res=1
while i<=n:
    print(res,end=" ")
    res=res+i
    i=i+1
# Out:
# 1 1 2 6 24 120 720 5040 40320 362880

# %%
#1
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    k=fact/i
    sum=sum+k
    i=i+1

print(sum)
# Out:
# 34.0

# %%
#2
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    if i%2==0:
        k=fact/i
        sum=sum+k
    else : 
        k=fact/i
        sum=sum-k
    i=i+1
print("the value of n is ",n)
print('The + - + - series is ',sum)
# Out:
# the value of n is  5
# The + - + - series is  -20.0

# %%
#3
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    if i%2==0:
        k=fact/i
        sum=sum-k
    else : 
        k=fact/i
        sum=sum+k
    i=i+1
print("the value of n is ",n)
print('The + - + - series is ',sum)
# Out:
# the value of n is  5
# The + - + - series is  20.0

# %%
#5
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    if i%2==0:
        k=i/fact
        sum=sum+k
    else : 
        k=i/fact
        sum=sum-k
    i=i+1
print("the value of n is ",n)
print('The + - + - series is ',sum)
# Out:
# the value of n is  5
# The + - + - series is  -0.37500000000000006

# %%
#4
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    k=i/fact
    sum=sum+k
    i=i+1

print(sum)
# Out:
# 2.708333333333333

# %%
#6
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    if i%2==0:
        k=i/fact
        sum=sum-k
    else : 
        k=i/fact
        sum=sum+k
    i=i+1
print("the value of n is ",n)
print('The + - + - series is ',sum)
# Out:
# the value of n is  5
# The + - + - series is  0.37500000000000006

# %%
#7
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    k=fact/i*2
    sum=sum+k
    i=i+1

print(sum)
# Out:
# 68.0

# %%
#8
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    if i%2==0:
        k=fact/i*2
        sum=sum+k
    else : 
        k=fact/i*2
        sum=sum-k
    i=i+1
print("the value of n is ",n)
print('The + - + - series is ',sum)
# Out:
# the value of n is  5
# The + - + - series is  -40.0

# %%
#9
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    if i%2==0:
        k=fact/i*2
        sum=sum-k
    else : 
        k=fact/i*2
        sum=sum+k
    i=i+1
print("the value of n is ",n)
print('The + - + - series is ',sum)
# Out:
# the value of n is  5
# The + - + - series is  22.876190476190477

# %%
#9
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    if i%2==0:
        k=fact/i*2
        sum=sum-k
    else : 
        k=fact/i*2
        sum=sum+k
    i=i+1
print("the value of n is ",n)
print('The + - + - series is ',sum)

# %%
#10
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    k=2*i-1
    sum=sum+(fact/k)
    i=i+1

print(sum)
# Out:
# 19.628571428571426

# %%
#9
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    if i%2==0:
        k=2*i-1
        sum=sum-(fact/k)
    else : 
        k=2*i-1
        sum=sum+(fact/k)
    i=i+1
print("the value of n is ",n)
print('The + - + - series is ',sum)
# Out:
# the value of n is  5
# The + - + - series is  11.438095238095238

# %%
#9
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    if i%2==0:
        k=2*i-1
        sum=sum+(fact/k)
    else : 
        k=2*i-1
        sum=sum-(fact/k)
    i=i+1
print("the value of n is ",n)
print('The + - + - series is ',sum)

# %%
#13
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    k=i*2/fact
    sum=sum+k
    i=i+1

print(sum)
# Out:
# 5.416666666666666

# %%
#14
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    if i%2==0:
        k=i*2/fact
        sum=sum-k
    else : 
        k=i*2/fact
        sum=sum+k
    i=i+1
print("the value of n is ",n)
print('The + - + - series is ',sum)
# Out:
# the value of n is  5
# The + - + - series is  0.7500000000000001

# %%
#14
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    if i%2==0:
        k=i*2/fact
        sum=sum+k
    else : 
        k=i*2/fact
        sum=sum-k
    i=i+1
print("the value of n is ",n)
print('The + - + - series is ',sum)
# Out:
# the value of n is  5
# The + - + - series is  -0.7500000000000001

# %%
#16
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    k=i*2-1
    sum=sum+k/fact
    i=i+1

print(sum)
# Out:
# 3.7

# %%
#9
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    if i%2==0:
        k=2*i-1
        sum=sum+(k/fact)
    else : 
        k=2*i-1
        sum=sum-(k/fact)
    i=i+1
print("the value of n is ",n)
print('The + - + - series is ',sum)
# Out:
# the value of n is  5
# The + - + - series is  -0.11666666666666668

# %%
#9
n=int(input("enter any number: "))
i=1
sum=0
fact=1
while i<=n:
    fact=fact*i
    if i%2==0:
        k=2*i-1
        sum=sum-(k/fact)
    else : 
        k=2*i-1
        sum=sum+(k/fact)
    i=i+1
print("the value of n is ",n)
print('The + - + - series is ',sum)
# Out:
# the value of n is  5
# The + - + - series is  0.11666666666666668

# %%
n=5
i=1
sum=0
fact=1

while i<=n:
    fact=fact*i
    if i%2!=0:
        sum=sum+fact
    
    i=i+1
    
print(sum)
# Out:
# 127

# %%
sum=0
i=1
n=int(input("enter any number :"))
sum=0
while n>0:
    r=n%10
    
    n=n//10

    sum=sum+r

print(sum)
# Out:
# 22

# %%
n=9
print(n/10)
print(n//10)
print(n%10)
# Out:
# 0.9
# 0
# 9

# %%
sum=0
i=1
rev=0
n=int(input("enter any number :"))
sum=0
while n>0:
    r=n%10
    n=n//10
    sum=sum*10+r
    rev=rev+r
print(sum)
print(rev)
# Out:
# 5296
# 22

# %%
sum=0

rev=0
n=int(input("enter any number :"))
i=n
sum=0
while n>0:
    r=n%10
    n=n//10
    sum=sum*10+r
    rev=rev+r
if sum==i:
        print("it is a pallandrom")
else:
        print("it is not a pallandrom")
# print(sum)
# print(rev)
# Out:
# it is a pallandrom

# %%
rev=0
n=int(input("enter any number :"))
m=n
sum=0
count=0
while m>0:
    count=count+1
    m=m//10
print(count)
while n>0:
    r=n%10
    n=n//10
    sum=sum+(r**count)
print(sum)
# print(sum)
# print(rev)
# Out:
# 3
# 216

# %%
#print febonnaci series 
n=9
febo=0
i=1
sum=1
a=-1
b=1
while sum<=n:
    sum=a+b
    print("febonaaci",sum)
    a=b
    b=sum
    i=i+1
# Out:
# febonaaci 0
# febonaaci 1
# febonaaci 1
# febonaaci 2
# febonaaci 3
# febonaaci 5
# febonaaci 8
# febonaaci 13

# %%
#print febonnaci series 
n=int(input("enter a number"))
febo=0
i=1
sum=0
a=-1
b=1
while i<=n:
    if n%i==0 :
        sum=sum+1
    
    i=i+1
if sum==2:
    print("prime")
else:
    print("no prime")
#break is an jumping statement whenever control found any break statement then controler will be transfer current executable block.
# Out:
# prime

# %%
n=int(input("enter any number"))
i=2
while i<n:
    if n%i==0:
        break
    i=i+1
if i==n:
    print("prime")
else :
    print("not a prime")
#flack is an special type of variable which can hold one output state
# Out:
# prime

# %%
n=int(input("enter any number"))
i=2
flag=1
while i<n//2:
    if n%i==0:
        flag=0
        break
    i=i+1
if flag==1:
    print("prime")
else :
    print("not a prime")
#flag is an special type of variable which can hold one output state
# Out:
# prime

# %%
n=5
i=1
sum=0
fact=1

while i<=n:
    fact=fact*i
    if i%2!=0:
        sum=sum+fact
    else:
        sum=sum-fact
    i=i+1
print(sum)
# Out:
# 101

# %%
n=5
i=1
sum=0
fact=1

while i<=n:
    fact=fact*i
    if i%2!=0:
        sum=sum-fact
    else:
        sum=sum+fact
    i=i+1
    
print(sum)
# Out:
# -101

# %%
n=int(input("enter"))
i=1
sum=0

while i<=n:
    fact=fact*i
    
    sum=sum+fact

    i=i+1
print(sum)
# Out:
# 38858408622593895215087124465709702611541520547840000000000000000000000000000000000000000000

# %%
age = int(input("Enter your age: "))

if age < 0:
    print("Invalid age")
if age >= 0 and age <= 12:
    print("You are a Child")
if age >= 13 and age <= 19:
    print("You are a Teen")
if age >= 20 and age <= 35:
    print("You are Young")
if age >= 60:
    print("You are Old")
# Out:
# young

# %% [markdown]
# Write a program for swapping of two integer variables using third variable.

# %%
a = int(input("Enter age: "))
if a <= 0:
    print("invalid")
elif a < 13:
    print("child")
elif a < 20:
    print("teen")
elif a < 60:
    print("young")
else:
    print("old")
# Out:
# child

# %% [markdown]
# Write a program to print last digit of a given number.

# %%
a=10
print(-a)
# Out:
# -10

# %%
a = int(input("Enter percentage: "))
if a < 0:
    print("invalid")
elif a < 34:
    print("fail")
elif a < 45:
    print("3rd division")
elif a < 60:
    print("2nd division")
elif a < 101:
    print("1 st division")
else:
    print("not more than 100")
# Out:
# 1 st division

# %%
a=int(input("enter a num "))
if a==1:
    print("it is one")
elif a==2 :
    if a==2:
        print("this is two")
elif(a==3):
    print("this is three")
else:
    print("choose a number between 1,2 and 3")
# Out:
# this is three
