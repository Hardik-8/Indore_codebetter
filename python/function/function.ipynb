# %%
def first():
    pass

# %%
def first():
    print("hello world")
first()
# Out:
# hello world

# %%
# a=int(input("enter first number"))
# b=int(input("enter second number"))
def add(a,b,c):
    a=int(input("a:"))
    b=int(input("b:"))
    c=a+b
    print("sum is ",c)
add()

# add(a,b)

# def subtract(a,b):
#     d=a-b
#     print("subtract is ",d)
# subtract(a,b)
# def multiply(a,b):
#     print(a*b)
# multiply(a,b)


# add(8,9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 8
#       6     c=a+b
#       7     print("sum is ",c)
# ----> 8 add()
#
# TypeError: add() missing 3 required positional arguments: 'a', 'b', and 'c'

# %%
def display():
    print("hello world")

print("scripts....")
# Out:
# scripts....

# %%
display()
# Out:
# hello world

# %%
def show():
    print("hello show")
show()
# Out:
# hello show

# %%
c=show()
# Out:
# hello show

# %%
def square():
    return [1,4,9,16,25,36,49]
square()
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
res=square()
print(res)
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
def square(x):
    square=x*x
    return square
# square(3)
print(square(6))
square(2)
# Out:
# 36
# 4

# %%
while True:
    print("\n\nEnter 1 for add\nEnter 2 for subtract\nEnter 3 for multiply\nEnter 4 for divide\nEnter 5 for modulas\nEnter 6 for exit")
    x=int(input("\nEnter any number "))
    
    if x==1:
        def add():
            a=int(input("Enter the first number"))
            b=int(input("enter the second number"))
            print("first number is :",a)
            print("first number is :",b)
            print("the sum is",a+b)
        add()
    elif x==2:
        def subtract():
            a=int(input("Enter the first number"))
            b=int(input("enter the second number"))
            print("first number is :",a)
            print("first number is :",b)
            print("the subtraction is",a-b)
        subtract()
    elif x==3:
        def multiplication():
            a=int(input("Enter the first number"))
            b=int(input("enter the second number"))
            print("first number is :",a)
            print("first number is :",b)
            print("the multipliication is",a*b)
        multiplication()
    elif x==4:
        def divide():
            a=int(input("Enter the first number"))
            b=int(input("enter the second number"))
            print("first number is :",a)
            print("first number is :",b)
            print("the devide is",a/b)
        divide()
    elif x==5:
        def modulas():
            a=int(input("Enter the first number"))
            b=int(input("enter the second number"))
            print("first number is :",a)
            print("first number is :",b)
            print("Modulas : ",a%b)
        modulas()
    elif x==6:
        break
    else :
        print("Invaild input ")
# Out:
# Enter 1 for add
# Enter 2 for subtract
# Enter 3 for multiply
# Enter 4 for divide
# Enter 5 for modulas
# Enter 6 for exit
# first number is : 1
# first number is : 2
# the sum is 3
#
#
# Enter 1 for add
# Enter 2 for subtract
# Enter 3 for multiply
# Enter 4 for divide
# Enter 5 for modulas
# Enter 6 for exit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 3
#       1 while True:
#       2     print("\n\nEnter 1 for add\nEnter 2 for subtract\nEnter 3 for multiply\nEnter 4 for divide\nEnter 5 for modulas\nEnter 6 for exit")
# ----> 3     x=int(input("\nEnter any number "))
#       5     if x==1:
#       6         def add():
#
# ValueError: invalid literal for int() with base 10: ''

# %%
a=int(input("Enter the first number"))
b=int(input("enter the second number"))
while True:
    print("\n\nEnter 1 for add\nEnter 2 for subtract\nEnter 3 for multiply\nEnter 4 for divide\nEnter 5 for modulas\nEnter 7 for floor\nEnter 6 for exit")
    x=int(input("\nEnter any number "))
    
    if x==1:
        def add():
            print("first number is :",a)
            print("first number is :",b)
            print("the sum is",a+b)
        add()
    elif x==2:
        def subtract():
            print("first number is :",a)
            print("first number is :",b)
            print("the subtraction is",a-b)
        subtract()
    elif x==3:
        def multiplication():
            print("first number is :",a)
            print("first number is :",b)
            print("the multipliication is",a*b)
        multiplication()
    elif x==4:
        def divide():
            print("first number is :",a)
            print("first number is :",b)
            print("the devide is",a/b)
        divide()
    elif x==5:
        def modulas():
            print("first number is :",a)
            print("first number is :",b)
            print("Modulas : ",a%b)
        modulas()
    elif x==7:
        def floor():
            print("Floor",a//b)
        floor()
    elif x==6:
        break
    else :
        print("Invaild input ")
# Out:
# Enter 1 for add
# Enter 2 for subtract
# Enter 3 for multiply
# Enter 4 for divide
# Enter 5 for modulas
# Enter 6 for exit
# first number is : 5
# first number is : 4
# the sum is 9
#
#
# Enter 1 for add
# Enter 2 for subtract
# Enter 3 for multiply
# Enter 4 for divide
# Enter 5 for modulas
# Enter 6 for exit
# Invaild input
#
#
# Enter 1 for add
# Enter 2 for subtract
# Enter 3 for multiply
# Enter 4 for divide
# Enter 5 for modulas
# Enter 6 for exit

# %%
# greater greatest banana hai

# %%
def display():
    print("hello world.....")
def show():
    print("Hello show.....")

display()
show()
# Out:
# hello world.....
# Hello show.....

# %%
def display():
    print("hello world.....")
    show()
def show():
    print("Hello show.....")
    
    
display()
show()
# ham eek fucntion ke andr show ko call kr sakta hai 
#inner fucntion kehlate hai tightly coupled hote hai 
# ham eek fucntion ke adner jab function banate hai tooo vo inner fution kehlata hai
# Out:
# hello world.....
# Hello show.....
# Hello show.....

# %%
def outer():
    print("outer")
    def inner():
        print("hello world")
    inner()
outer()
#isko ham bahar call nahi kr sakte hai 
# jab ham kisi fucntion ke ander se kisi dusre function ko call krte hai too vo recursive function kehlata hai  (recursion)
# a fucntion jo khhud ko hii khud ki body me se call kr le vo recursive function kehlate hai 
# a recursive fucntion to be accouped memory in the form of reverse order stack # this is the fucntion 
# stackjo hota hai vo follow krta hai last in first out
# Out:
# outer
# hello world

# %%
# find the factorial of given number using function 
def factorical(x):
    if x==1:
        f=1
    else:
        f=x+factorical(x-1)
    return f
n=int(input("Enter any choice : "))
result=factorical(n)
print(result)
# Out:
# 15

# %%
# find the factorial of given number using function 
def factorical(x):
    if x==1:
        f=1
    else:
        f=x*factorical(x-1)
    return f
n=int(input("Enter any choice : "))
result=factorical(n)
print(result)
# Out:
# 120

# %%
find the sum of input digit
reverse of input digit

# %%
def sum_input():
# Out:
#   Cell In[32], line 1
#     def sum_input():
#                     ^
# SyntaxError: incomplete input

# %%
# print fibonacci series for n terms 

def fibonacci(n):
    if n == 0:
        return 0
    if n == 1:
        return 1
    return fibonacci(n-1) + fibonacci(n-2)

terms = int(input("Enter number of terms: "))

print("Fibonacci Series:")
for i in range(terms):
    print(fibonacci(i), end=" ")
# Out:
# Fibonacci Series:
# 0 1 1 2 3

# %%
def reverse_num(n):
    if len(n) == 1:
        return n
    return n[-1] + reverse_num(n[:-1])

num = input("Enter number: ")
print("Reverse:", reverse_num(num))
# Out:
# Reverse: 7545

# %%
def sum_digits(n):
    if n == 0:
        return 0
    return (n % 10) + sum_digits(n // 10)

num = int(input("Enter number: "))
print("Sum of digits:", sum_digits(num))
# Out:
# Sum of digits: 18

# %%
def display():
    a=12
    print("Hello world")
    show(a)
def show(a=0):
    print("HELLO SHOW ")
    print(a)
display()
show(a=2)
show(a=12)
show()
show(123)

# function overloading - whenver we define more than one fucntion with having same name but passing arguement is to be diffrent is called function overloading 
# with the help of fucntion overloading we can acchive static polymorphims.
# Out:
# Hello world
# HELLO SHOW
# 12
# HELLO SHOW
# 2
# HELLO SHOW
# 12
# HELLO SHOW
# 0
# HELLO SHOW
# 123

# %%
#overriding - whenever we define more than one fucntion with the same name but passing arguiement is also same is called function overriding. 
# with the help of fucntion overriding we can acchive dynamic polymorphism.
# decorater - in python a  is a design pattern that allow you to modify the fucntionlity of fucntion by wrapping it in another fucntion. 
def one():
    print("HELLO")
def two():
    print("two")
ob=one
ob()
pr=print
pr("hello world")
on=input
on("enter the number")
# Out:
# HELLO
# hello world
# '5'

# %%
def display():
    # global a
    a=12
    print("Hello world")
    # show()
def show():
        print("HELLO SHOW ")
        print(a)
def operate(fucntion):
      fucntion()
operate(display)


# ob=display()
# ob()
# Out:
# Hello world

# %%
def display():
    global a
    a=12
    print("Hello world")
    # show(a)
    def show(a=0):
        print("HELLO SHOW ")
        print(a)
    show(a)
display()
# Out:
# Hello world
# HELLO SHOW
# 12
