# %%
import numpy as np

# %%
l4=[
    [
    [ [10,20],[30,40]],
    [ [11,21],[31,41]]
    ],
    [
    [[90,20],[20,11]],
    [[20,50],[40,60]]
    ]
]

# %%
ar4=np.array(l4)

# %%
print(ar4.shape)
# Out:
# (2, 2, 2, 2)

# %%
print(ar4.ndim)
# Out:
# 4

# %%
ar4[0,0,0,0]
# Out:
# np.int64(10)

# %%
ar4[0,0,1,0]
# Out:
# np.int64(30)

# %%
ar4[0,1,0,0]
# Out:
# np.int64(11)

# %%
ar4
# Out:
# array([[[[10, 20],
#          [30, 40]],
#
#         [[11, 21],
#          [31, 41]]],
#
#
#        [[[90, 20],
#          [20, 11]],
#
#         [[20, 50],
#          [40, 60]]]])

# %%
ar4[0,0,1,0]
# Out:
# np.int64(30)

# %%
ar4[1,0,0,0]
# Out:
# np.int64(90)

# %%
ar4[:2,:2,:1,:1]
# Out:
# array([[[[10]],
#
#         [[11]]],
#
#
#        [[[90]],
#
#         [[20]]]])

# %%
ar4[:2,:2,:1,:1].ndim
# Out:
# 4

# %%
ar4[:2,:2,:1,:1].shape
# Out:
# (2, 2, 1, 1)

# %%
ar4[:2,:2,:1,:1].mean()
# Out:
# np.float64(32.75)
