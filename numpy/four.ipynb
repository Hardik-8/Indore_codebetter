# %%
import numpy as np

# %%
l4=[
    [
    [ [10,20],[30,40]],
    [ [11,21],[31,41]]
    ],
    [
    [[90,20],[20,11]],
    [[20,50],[40,60]]
    ]
]

# %%
ar4=np.array(l4)

# %%
print(ar4.shape)
# Out:
# (2, 2, 2, 2)

# %%
print(ar4.ndim)
# Out:
# 4

# %%
ar4[0,0,0,0]
# Out:
# np.int64(10)

# %%
ar4[0,0,1,0]
# Out:
# np.int64(30)

# %%
ar4[0,1,0,0]
# Out:
# np.int64(11)

# %%
ar4
# Out:
# array([[[[10, 20],
#          [30, 40]],
#
#         [[11, 21],
#          [31, 41]]],
#
#
#        [[[90, 20],
#          [20, 11]],
#
#         [[20, 50],
#          [40, 60]]]])

# %%
ar4[0,0,1,0]
# Out:
# np.int64(30)

# %%
ar4[1,0,0,0]
# Out:
# np.int64(90)

# %%
ar4[:2,:2,:1,:1]
# Out:
# array([[[[10]],
#
#         [[11]]],
#
#
#        [[[90]],
#
#         [[20]]]])

# %%
ar4[:2,:2,:1,:1].ndim
# Out:
# 4

# %%
ar4[:2,:2,:1,:1].shape
# Out:
# (2, 2, 1, 1)

# %%
ar4[:2,:2,:1,:1].mean()
# Out:
# np.float64(32.75)

# %%
for i in range(ar4.shape[0]):
    for j in range(ar4.shape[1]):
        for k in range(ar4.shape[2]):
            for l in range(ar4.shape[3]):
                print(ar4[i,j,k,l],end=" ")
# Out:
# 10 20 30 40 11 21 31 41 90 20 20 11 20 50 40 60

# %%
ar4
# Out:
# array([[[[10, 20],
#          [30, 40]],
#
#         [[11, 21],
#          [31, 41]]],
#
#
#        [[[90, 20],
#          [20, 11]],
#
#         [[20, 50],
#          [40, 60]]]])

# %%
for i in range(ar4.shape[0]):
    # for j in i:
    print(a)
# Out:
# [[[[10 20]
#    [30 40]]
#
#   [[11 21]
#    [31 41]]]
#
#
#  [[[90 20]
#    [20 11]]
#
#   [[20 50]
#    [40 60]]]]
# [[[[10 20]
#    [30 40]]
#
#   [[11 21]
#    [31 41]]]
#
#
#  [[[90 20]
#    [20 11]]
#
#   [[20 50]
#    [40 60]]]]

# %%
ar4
# Out:
# array([[[[10, 20],
#          [30, 40]],
#
#         [[11, 21],
#          [31, 41]]],
#
#
#        [[[90, 20],
#          [20, 11]],
#
#         [[20, 50],
#          [40, 60]]]])

# %%
ar4[:2,:2,0:2,1:2]
# Out:
# array([[[[20],
#          [40]],
#
#         [[21],
#          [41]]],
#
#
#        [[[20],
#          [11]],
#
#         [[50],
#          [60]]]])

# %%
ar4[:1,:2,:2,:2]
# Out:
# array([[[[10, 20],
#          [30, 40]],
#
#         [[11, 21],
#          [31, 41]]]])

# %%
m=ar4[:1]
q=ar4[:2]
a=ar4[:2]
b=ar4[:2]

for i in m:
    for j in q:
        for k in a:
            for l in b:
                print(ar4[i,j,k,l])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[63], line 10
#       8 for k in a:
#       9     for l in b:
# ---> 10         print(ar4[i,j,k,l])
#
# IndexError: index 10 is out of bounds for axis 0 with size 2

# %%
for i in ar4:
    for j in i:
        for k in j:
            for l in k:
                print(l)
# Out:
# 10
# 20
# 30
# 40
# 11
# 21
# 31
# 41
# 90
# 20
# 20
# 11
# 20
# 50
# 40
# 60
