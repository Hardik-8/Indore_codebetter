# %%
import numpy as np 
import math


l1=[10,20,30,40,50]
e1=5

for i in range(len(l1)):
    add=l1[i]+5
print(l1)
# Out:
# [10, 20, 30, 40, 50]

# %%
n1=np.array(l1)
n2=n1+e1
print(n2)
len(l1)
# Out:
# [15 25 35 45 55]
# 5

# %%
l1=[2,4,6,8]
l2=[3,6,9,12]
n1=np.array(l1)
n2=np.array(l2)
l3=n1+n2
l4=n1-n2
print(l3)
print(l4)
l5=n1*n2
l6=n1/n2
print(l5)
print(l6)
l7=n1%n2
print(l7)
l8=n1**n2
print(l8)
l9=n1//n2
print(l9)
# Out:
# [ 5 10 15 20]
# [-1 -2 -3 -4]
# [ 6 24 54 96]
# [0.66666667 0.66666667 0.66666667 0.66666667]
# [2 4 6 8]
# [          8        4096    10077696 68719476736]
# [0 0 0 0]

# %%
l3=[]
l4=[]
for i in range(len(l1)):
    add=l1[i]+l2[i]
    sub=l1[i]-l2[i]
    l3.append(add)
    l4.append(sub)

print(l3)
print(l4)
# Out:
# [5, 10, 15, 20]
# [-1, -2, -3, -4]

# %%
n1.dtype
# Out:
# dtype('int64')

# %%
n1.size
# Out:
# 4

# %%
n1.ndim
# Out:
# 1

# %%
n1.shape
# Out:
# (4,)

# %%
n1.itemsize
# Out:
# 8

# %%
l5=[[1,2,3,4,5],[9,2,3,4,5]]
m=np.array(l5)
print(m)
# Out:
# [[1 2 3 4 5]
#  [9 2 3 4 5]]

# %%
q=np.array([1,2,3,4,5,6])
print(q)
i=0
while i < q.size:
    print(q[i])
    i+=1
# Out:
# [1 2 3 4 5 6]
# 1
# 2
# 3
# 4
# 5
# 6

# %%
salary=np.array([130200,20000,30000,400000,500000])
tax=salary*0.10
increment=salary*0.20
gs_sal=salary+increment-tax
print(tax)
print(tax.sum())
print(salary.sum())
print(np.sum(tax))
print(gs_sal)
# Out:
# [13020.  2000.  3000. 40000. 50000.]
# 108020.0
# 1080200
# 108020.0
# [143220.  22000.  33000. 440000. 550000.]

# %%
ta=salary*0.5
da=salary*0.10
gs=salary+ta+da
print(gs)
# Out:
# [208320.  32000.  48000. 640000. 800000.]
