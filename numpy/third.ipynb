# %%
import numpy as np

# %%
l1=[10,20,30,40]
ar1=np.array(l1)

# %%
#3d ke ander jitne 2d hoge vo sare block ki tarah consider hoge

# %%
l3=[
    [ [ 10,20,30] , [20,30,40]],
    [ [40,20,30 ], [ 30,40,50]]
]

ar3=np.array(l3)

# %%
l4=[
    [ [40,20,50] , [20,60,40]],
    [ [90,20,80 ], [50,40,50]]
]

ar4=np.array(l4)

# %%
print(ar3)
# Out:
# [[[10 20 30]
#   [20 30 40]]
#
#  [[40 20 30]
#   [30 40 50]]]

# %%
ar3.size
# Out:
# 12

# %%
ar3.ndim
# Out:
# 3

# %%
ar3.shape
# (a = block , b = row , c = column)
# Out:
# (2, 2, 3)

# %%
ar3.min()
# Out:
# np.int64(10)

# %%
ar3.max()
# Out:
# np.int64(50)

# %%
ar3.mean()
# Out:
# np.float64(30.0)

# %%
ar3.var()
# Out:
# np.float64(116.66666666666667)

# %%
#har 2d ke ander jitni bhi 1d hote hai unko row consider krna hota hai
ar3[0]
# Out:
# array([[10, 20, 30],
#        [20, 30, 40]])

# %%
ar3[0,0]
# Out:
# array([10, 20, 30])

# %%
ar3[0,0,0
    ]
# Out:
# np.int64(10)

# %%
ar3[1,0,0]
# Out:
# np.int64(40)

# %%
ar3[1,0,2]
# Out:
# np.int64(30)

# %%
# array ka size equal hona chaiheye kuch bhi ho

# %%
ar3[0][1].mean()
# Out:
# np.float64(30.0)

# %%
ar3[0][0].mean()
# Out:
# np.float64(20.0)

# %%
ar3
# Out:
# array([[[10, 20, 30],
#         [20, 30, 40]],
#
#        [[40, 20, 30],
#         [30, 40, 50]]])

# %%
print(ar3[1,1,1],ar3[1,0,1])
# Out:
# 40 20

# %% [markdown]
# ### slicing

# %%
ar3
# Out:
# array([[[10, 20, 30],
#         [20, 30, 40]],
#
#        [[40, 20, 30],
#         [30, 40, 50]]])

# %%
ar3[0:2,0:2,0:1]
# Out:
# array([[[10],
#         [20]],
#
#        [[40],
#         [30]]])

# %%
for i in ar3:
    for j in i:
       for k in j:
           print(k,end=" ")
    #  print(j)
# Out:
# 10 20 30 20 30 40 40 20 30 30 40 50

# %%
ar3
# Out:
# array([[[10, 20, 30],
#         [20, 30, 40]],
#
#        [[40, 20, 30],
#         [30, 40, 50]]])

# %%
for i in range(ar3.shape[0]):
    for j in range(ar3.shape[1]):
        for k in range(ar3.shape[2]):
            print(ar3[i,j,k],end=" ")
# Out:
# 10 20 30 20 30 40 40 20 30 30 40 50

# %%
ar1=ar3.flatten()

# %%
ar1
# Out:
# array([10, 20, 30, 20, 30, 40, 40, 20, 30, 30, 40, 50])

# %%
ar2=ar3.reshape(3,4)

# %%
ar2
# Out:
# array([[10, 20, 30, 20],
#        [30, 40, 40, 20],
#        [30, 30, 40, 50]])

# %%
ar3
# Out:
# array([[[10, 20, 30],
#         [20, 30, 40]],
#
#        [[40, 20, 30],
#         [30, 40, 50]]])

# %%
ar3.size
# Out:
# 12

# %%
ar2.reshape(2,2,3)
# Out:
# array([[[10, 20, 30],
#         [20, 30, 40]],
#
#        [[40, 20, 30],
#         [30, 40, 50]]])

# %%
np.add
np.subtract
np.divide
np.multiply
np.floor
# Out:
# <ufunc 'floor'>

# %%
np.add(ar3,ar4)
# Out:
# array([[[ 50,  40,  80],
#         [ 40,  90,  80]],
#
#        [[130,  40, 110],
#         [ 80,  80, 100]]])

# %%
np.subtract(ar3,ar4
            )
# Out:
# array([[[-30,   0, -20],
#         [  0, -30,   0]],
#
#        [[-50,   0, -50],
#         [-20,   0,   0]]])

# %%
np.multiply(ar3,ar4)
# Out:
# array([[[ 400,  400, 1500],
#         [ 400, 1800, 1600]],
#
#        [[3600,  400, 2400],
#         [1500, 1600, 2500]]])

# %%
np.divide(ar3,ar4
          )
# Out:
# array([[[0.25      , 1.        , 0.6       ],
#         [1.        , 0.5       , 1.        ]],
#
#        [[0.44444444, 1.        , 0.375     ],
#         [0.6       , 1.        , 1.        ]]])

# %%
np.floor(ar3,ar4)
# Out:
# array([[[10, 20, 30],
#         [20, 30, 40]],
#
#        [[40, 20, 30],
#         [30, 40, 50]]])

# %%
np.vecdot(ar3,ar4)
# Out:
# array([[1400, 2900],
#        [2900, 5000]])
